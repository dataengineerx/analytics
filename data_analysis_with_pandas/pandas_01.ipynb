# %%
import pandas as pd
import datetime
from matplotlib import pyplot as plt
from matplotlib import style
import numpy as np
import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)
from pandas_datareader import data as pdr

start = datetime.datetime(2010, 1, 1)
end = datetime.datetime.now()

df = pdr.get_data_yahoo('XOM', start=start, end=end)

df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High        Low      Close  Adj Close    Volume
# Date
# 2010-01-04   68.720001   69.260002  68.190002  69.150002  40.611721  27809100
# 2010-01-05   69.190002   69.449997  68.800003  69.419998  40.770306  30174700
# 2010-01-06   69.449997   70.599998  69.339996  70.019997  41.122696  35044700
# 2010-01-07   69.900002   70.059998  69.419998  69.800003  40.993481  27192100
# 2010-01-08   69.690002   69.750000  69.220001  69.519997  40.829033  24891800
# ...                ...         ...        ...        ...        ...       ...
# 2024-01-12  100.139999  100.650002  99.169998  99.949997  99.949997  18032100
# 2024-01-16   99.820000  100.010002  97.529999  97.690002  97.690002  20235700
# 2024-01-17   96.599998   97.959999  96.580002  96.980003  96.980003  18384000
# 2024-01-18   97.000000   97.089996  95.820000  96.800003  96.800003  20940300
# 2024-01-19   96.720001   97.015602  96.410004  96.724998  96.724998  11279523
#
# [3535 rows x 6 columns]

# %%
df['Adj Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
style.use('fivethirtyeight')
plt.legend()
df['High'].plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <Axes: xlabel='Date'>

# %%
df.loc['2010-01-06']
# Out:
# Open         6.945000e+01
# High         7.060000e+01
# Low          6.934000e+01
# Close        7.002000e+01
# Adj Close    4.112270e+01
# Volume       3.504470e+07
# Name: 2010-01-06 00:00:00, dtype: float64

# %%
ndf['Date']
# Out:
# 0      2010-01-04
# 1      2010-01-05
# 2      2010-01-06
# 3      2010-01-07
# 4      2010-01-08
#           ...
# 3530   2024-01-12
# 3531   2024-01-16
# 3532   2024-01-17
# 3533   2024-01-18
# 3534   2024-01-19
# Name: Date, Length: 3535, dtype: datetime64[ns]
